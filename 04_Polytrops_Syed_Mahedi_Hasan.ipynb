# %%
import numpy as np, copy
import matplotlib.pyplot as plt
# %matplotlib inline
from astropy import constants as const
import astropy.units as u
from astropy.units import cds
cds.enable()

# %%
def read_model(file):
    cols=np.array([1,2,3,4,5,29,66])-1
    return np.genfromtxt(file, skip_header=5, names=True, usecols=cols)

# %%
def Lane_zp(x, y, z, n):
    if y<0:
        y=0
    return -2.0 * z / x - y**n

def poly_num(n, h=0.01, x_end=16.0, xinit=0.00001):
    #The step and the ending eps value is initialized
    #n: polytrope index
    #h: 0.05 step size
    #x_end: 16.0
    
    #The starting value was initialized
    
    x = xinit
    y= 1 - ( 1.0/6.0 * x**2) + ( n/120.0 * x**4 ) - ( n*(8*n-5)/15120.0 * x**6 )
    z=- ( 1.0/6.0 * 2 * x ) + ( n/120.0 * 4 * x**3 ) - (n*(8*n-5)/15120.0 * 6 * x**5)
    zp=-( 1.0/6.0 * 2 ) + ( n/120.0 * 12 * x**2 ) - ( n*(8*n-5)/15120.0 * 6*5 * x**4)
    
    eps=np.array([h])
    theta=np.array([y])
    theta_prim = np.array([z])
    
    #Make the calculation until we reach x_end, or theta goes to zero
    while (x<x_end) and (y>0):
        K1 = h * z
        L1 = h * Lane_zp(x, y, z, n)
        K2 = h * (z + L1/2.0)
        L2 = h * Lane_zp(x+h/2.0, y+K1/2.0, z+L1/2.0, n)
        K3 = h * (z + L2/2.0)
        L3 = h * Lane_zp(x+h/2.0, y+K2/2.0, z+L2/2.0, n)
        K4 = h * (z + L3/2.0)
        L4 = h * Lane_zp(x+h, y+K3, z+L3, n)

        y = y + K1/6.0 + K2/3.0 + K3/3.0 + K4/6.0
        z = z + L1/6.0 + L2/3.0 + L3/3.0 + L4/6.0

        x = x + h

        eps = np.append(eps,x)
        theta = np.append(theta, y)
        theta_prim = np.append(theta_prim, z)
#         print("eps=",eps,"theta=",theta,"theta_prim=",theta_prim)
    
    return eps[0:eps.size-1], theta[0:theta.size-1], theta_prim[0:theta_prim.size-1]

# %%
def poly_n0(eps):
    #eps is an array of epsilon values
    return 1.0 - eps**2

def poly_n1(eps):
    return np.sin(eps)/eps

def poly_n5(eps):
    return (1.0 + eps**2.0/3.0)**(-0.5)

# %%
fig, ax = plt.subplots(1,1,figsize=(12,8))
plt.rcParams.update({'font.size':18})
plt.rcParams.update({'font.family':'Times New Roman'})

ax.set_ylim(0,1)

#Analytic solutions

#Define a set of eps values
eps = np.linspace(0.01,16,100)

ax.plot(eps,poly_n0(eps),label='n = 0 (analytic)')
ax.plot(eps,poly_n1(eps),label='n=1 (analytic)')
ax.plot(eps,poly_n5(eps),label='n=5 (analytic)')
plt.xlabel("epsilon")
plt.ylabel("theta")

#Numerical solutions
#the function poly_num(n) will return
#an array of eps_values, an array of dTheta/dEps at Eps1.

n=[0,1,2,3,4,5,6]

for item in n:
    eps, theta, theta_p = poly_num(item)
    str1=('n=%d (numerical)')%item
    ax.plot(eps, theta,ls='--',label=str1)

ax.legend(loc=0, fontsize=15)
plt.tight_layout()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
fig, ax = plt.subplots(1,1,figsize=(12,8))
plt.rcParams.update({'font.size':18})
plt.rcParams.update({'font.family':'Times New Roman'})

ax.set_xlim(0,1)
ax.set_ylim(0,1)

#MESA solar model
mesa = read_model('https://github.com/veropetit/PHYS633-S2022/blob/300c8aadb29a2c6176ba371d3df1ccf3a92e7556/L04-Polytrops/04-MESAdatafile.txt')

#In the mesa model, the first element [0] correspond to the surface,
#and the last element [mesa.size-1] correspond to the center.

mesa_r = 10**(mesa['logR']-mesa['logR'][0])
mesa_rho = 10**(mesa['logRho']-mesa['logRho'][mesa.size-1]) #the density is given in cgs
ax.plot(mesa_r, mesa_rho, c="red", lw=2, label='MESA')

#numerical solutions 
n=[1,2,3,4,5]
for item in n:
    eps, theta, theta_prim = poly_num(item)
    eps1 = eps[eps.size-1]
    str1=('n=%d (numerical)')%item
    ax.plot(eps/eps1, theta**item,ls='--',label=str1)
    
plt.xlabel('eps/eps1')
plt.ylabel('theta')

ax.legend(loc=0, fontsize=15)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-cfe877292926> in <module>
#       7
#       8 #MESA solar model
# ----> 9 mesa = read_model('https://github.com/veropetit/PHYS633-S2022/blob/300c8aadb29a2c6176ba371d3df1ccf3a92e7556/L04-Polytrops/04-MESAdatafile.txt')
#      10
#      11 #In the mesa model, the first element [0] correspond to the surface,
#
# <ipython-input-8-c23b2bd365af> in read_model(file)
#       1 def read_model(file):
#       2     cols=np.array([1,2,3,4,5,29,66])-1
# ----> 3     return np.genfromtxt(file, skip_header=5, names=True, usecols=cols)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    2122             # Raise an exception ?
#    2123             if invalid_raise:
# -> 2124                 raise ValueError(errmsg)
#    2125             # Issue a warning ?
#    2126             else:
#
# ValueError: Some errors were detected !
#     Line #7 (got 6 columns instead of 7)
#     Line #8 (got 1 columns instead of 7)
#     Line #9 (got 2 columns instead of 7)
#     Line #10 (got 3 columns instead of 7)
#     Line #11 (got 3 columns instead of 7)
#     Line #12 (got 3 columns instead of 7)
#     Line #13 (got 3 columns instead of 7)
#     Line #14 (got 4 columns instead of 7)
#     Line #15 (got 3 columns instead of 7)
#     Line #19 (got 53 columns instead of 7)
#     Line #21 (got 6 columns instead of 7)
#     Line #22 (got 6 columns instead of 7)
#     Line #23 (got 6 columns instead of 7)
#     Line #24 (got 6 columns instead of 7)
#     Line #29 (got 5 columns instead of 7)
#     Line #30 (got 5 columns instead of 7)
#     Line #31 (got 5 columns instead of 7)
#     Line #32 (got 5 columns instead of 7)
#     Line #33 (got 5 columns instead of 7)
#     Line #34 (got 5 columns instead of 7)
#     Line #35 (got 5 columns instead of 7)
#     Line #36 (got 5 columns instead of 7)
#     Line #37 (got 5 columns instead of 7)
#     Line #38 (got 5 columns instead of 7)
#     Line #39 (got 5 columns instead of 7)
#     Line #40 (got 5 columns instead of 7)
#     Line #41 (got 5 columns instead of 7)
#     Line #42 (got 5 columns instead of 7)
#     Line #43 (got 5 columns instead of 7)
#     Line #44 (got 5 columns instead of 7)
#     Line #45 (got 5 columns instead of 7)
#     Line #46 (got 5 columns instead of 7)
#     Line #47 (got 5 columns instead of 7)
#     Line #48 (got 5 columns instead of 7)
#     Line #49 (got 5 columns instead of 7)
#     Line #50 (got 5 columns instead of 7)
#     Line #51 (got 5 columns instead of 7)
#     Line #52 (got 5 columns instead of 7)
#     Line #53 (got 5 columns instead of 7)
#     Line #54 (got 5 columns instead of 7)
#     Line #55 (got 5 columns instead of 7)
#     Line #56 (got 5 columns instead of 7)
#     Line #57 (got 5 columns instead of 7)
#     Line #58 (got 5 columns instead of 7)
#     Line #59 (got 5 columns instead of 7)
#     Line #60 (got 5 columns instead of 7)
#     Line #61 (got 5 columns instead of 7)
#     Line #62 (got 5 columns instead of 7)
#     Line #63 (got 5 columns instead of 7)
#     Line #64 (got 5 columns instead of 7)
#     Line #65 (got 5 columns instead of 7)
#     Line #68 (got 7 columns instead of 7)
#     Line #74 (got 13 columns instead of 7)
#     Line #76 (got 4 columns instead of 7)
#     Line #79 (got 5 columns instead of 7)
#     Line #82 (got 4 columns instead of 7)
#     Line #84 (got 3 columns instead of 7)
#     Line #85 (got 3 columns instead of 7)
#     Line #86 (got 3 columns instead of 7)
#     Line #87 (got 3 columns instead of 7)
#     Line #88 (got 3 columns instead of 7)
#     Line #90 (got 4 columns instead of 7)
#     Line #92 (got 5 columns instead of 7)
#     Line #101 (got 3 columns instead of 7)
#     Line #105 (got 3 columns instead of 7)
#     Line #107 (got 16 columns instead of 7)
#     Line #108 (got 5 columns instead of 7)
#     Line #109 (got 4 columns instead of 7)
#     Line #110 (got 3 columns instead of 7)
#     Line #111 (got 4 columns instead of 7)
#     Line #112 (got 33 columns instead of 7)
#     Line #113 (got 58 columns instead of 7)
#     Line #115 (got 3 columns instead of 7)
#     Line #118 (got 3 columns instead of 7)
#     Line #122 (got 3 columns instead of 7)
#     Line #124 (got 3 columns instead of 7)
#     Line #127 (got 4 columns instead of 7)
#     Line #128 (got 4 columns instead of 7)
#     Line #129 (got 4 columns instead of 7)
#     Line #130 (got 4 columns instead of 7)
#     Line #132 (got 4 columns instead of 7)
#     Line #134 (got 2 columns instead of 7)
#     Line #136 (got 5 columns instead of 7)
#     Line #138 (got 25 columns instead of 7)
#     Line #142 (got 4 columns instead of 7)
#     Line #143 (got 6 columns instead of 7)
#     Line #146 (got 3 columns instead of 7)
#     Line #148 (got 3 columns instead of 7)
#     Line #150 (got 3 columns instead of 7)
#     Line #152 (got 4 columns instead of 7)
#     Line #153 (got 6 columns instead of 7)
#     Line #154 (got 5 columns instead of 7)
#     Line #156 (got 3 columns instead of 7)
#     Line #157 (got 5 columns instead of 7)
#     Line #160 (got 4 columns instead of 7)
#     Line #162 (got 1 columns instead of 7)
#     Line #164 (got 7 columns instead of 7)
#     Line #167 (got 4 columns instead of 7)
#     Line #168 (got 2 columns instead of 7)
#     Line #169 (got 6 columns instead of 7)
#     Line #170 (got 9 columns instead of 7)
#     Line #171 (got 1 columns instead of 7)
#     Line #177 (got 5 columns instead of 7)
#     Line #178 (got 5 columns instead of 7)
#     Line #179 (got 9 columns instead of 7)
#     Line #180 (got 13 columns instead of 7)
#     Line #181 (got 3 columns instead of 7)
#     Line #182 (got 1 columns instead of 7)
#     Line #184 (got 10 columns instead of 7)
#     Line #185 (got 6 columns instead of 7)
#     Line #186 (got 13 columns instead of 7)
#     Line #187 (got 12 columns instead of 7)
#     Line #188 (got 54 columns instead of 7)
#     Line #189 (got 1 columns instead of 7)
#     Line #190 (got 1 columns instead of 7)
#     Line #192 (got 2 columns instead of 7)
#     Line #193 (got 2 columns instead of 7)
#     Line #194 (got 11 columns instead of 7)
#     Line #195 (got 3 columns instead of 7)
#     Line #196 (got 1 columns instead of 7)
#     Line #197 (got 1 columns instead of 7)
#     Line #198 (got 1 columns instead of 7)
#     Line #199 (got 1 columns instead of 7)
#     Line #201 (got 4 columns instead of 7)
#     Line #202 (got 15 columns instead of 7)
#     Line #203 (got 5 columns instead of 7)
#     Line #204 (got 4 columns instead of 7)
#     Line #205 (got 4 columns instead of 7)
#     Line #206 (got 1 columns instead of 7)
#     Line #207 (got 1 columns instead of 7)
#     Line #208 (got 1 columns instead of 7)
#     Line #209 (got 1 columns instead of 7)
#     Line #212 (got 11 columns instead of 7)
#     Line #213 (got 14 columns instead of 7)
#     Line #214 (got 7 columns instead of 7)
#     Line #215 (got 3 columns instead of 7)
#     Line #216 (got 12 columns instead of 7)
#     Line #217 (got 16 columns instead of 7)
#     Line #218 (got 1 columns instead of 7)
#     Line #219 (got 15 columns instead of 7)
#     Line #220 (got 18 columns instead of 7)
#     Line #221 (got 1 columns instead of 7)
#     Line #222 (got 1 columns instead of 7)
#     Line #223 (got 14 columns instead of 7)
#     Line #224 (got 8 columns instead of 7)
#     Line #226 (got 1 columns instead of 7)
#     Line #227 (got 21 columns instead of 7)
#     Line #228 (got 14 columns instead of 7)
#     Line #229 (got 58 columns instead of 7)
#     Line #230 (got 1 columns instead of 7)
#     Line #231 (got 1 columns instead of 7)
#     Line #232 (got 3 columns instead of 7)
#     Line #233 (got 3 columns instead of 7)
#     Line #234 (got 1 columns instead of 7)
#     Line #237 (got 1 columns instead of 7)
#     Line #239 (got 1 columns instead of 7)
#     Line #240 (got 21 columns instead of 7)
#     Line #241 (got 14 columns instead of 7)
#     Line #242 (got 41 columns instead of 7)
#     Line #243 (got 1 columns instead of 7)
#     Line #244 (got 1 columns instead of 7)
#     Line #245 (got 3 columns instead of 7)
#     Line #246 (got 4 columns instead of 7)
#     Line #247 (got 1 columns instead of 7)
#     Line #250 (got 1 columns instead of 7)
#     Line #252 (got 1 columns instead of 7)
#     Line #253 (got 21 columns instead of 7)
#     Line #254 (got 14 columns instead of 7)
#     Line #255 (got 54 columns instead of 7)
#     Line #256 (got 1 columns instead of 7)
#     Line #257 (got 1 columns instead of 7)
#     Line #258 (got 3 columns instead of 7)
#     Line #259 (got 4 columns instead of 7)
#     Line #260 (got 1 columns instead of 7)
#     Line #263 (got 1 columns instead of 7)
#     Line #265 (got 1 columns instead of 7)
#     Line #266 (got 21 columns instead of 7)
#     Line #267 (got 14 columns instead of 7)
#     Line #268 (got 65 columns instead of 7)
#     Line #269 (got 1 columns instead of 7)
#     Line #270 (got 1 columns instead of 7)
#     Line #271 (got 3 columns instead of 7)
#     Line #272 (got 3 columns instead of 7)
#     Line #273 (got 1 columns instead of 7)
#     Line #276 (got 1 columns instead of 7)
#     Line #278 (got 1 columns instead of 7)
#     Line #279 (got 21 columns instead of 7)
#     Line #280 (got 14 columns instead of 7)
#     Line #282 (got 1 columns instead of 7)
#     Line #283 (got 1 columns instead of 7)
#     Line #284 (got 3 columns instead of 7)
#     Line #285 (got 5 columns instead of 7)
#     Line #286 (got 1 columns instead of 7)
#     Line #289 (got 1 columns instead of 7)
#     Line #291 (got 1 columns instead of 7)
#     Line #292 (got 23 columns instead of 7)
#     Line #293 (got 14 columns instead of 7)
#     Line #294 (got 58 columns instead of 7)
#     Line #295 (got 1 columns instead of 7)
#     Line #296 (got 1 columns instead of 7)
#     Line #297 (got 4 columns instead of 7)
#     Line #298 (got 3 columns instead of 7)
#     Line #299 (got 1 columns instead of 7)
#     Line #302 (got 1 columns instead of 7)
#     Line #304 (got 1 columns instead of 7)
#     Line #305 (got 21 columns instead of 7)
#     Line #306 (got 14 columns instead of 7)
#     Line #307 (got 36 columns instead of 7)
#     Line #308 (got 1 columns instead of 7)
#     Line #309 (got 1 columns instead of 7)
#     Line #310 (got 3 columns instead of 7)
#     Line #311 (got 4 columns instead of 7)
#     Line #312 (got 1 columns instead of 7)
#     Line #315 (got 1 columns instead of 7)
#     Line #317 (got 1 columns instead of 7)
#     Line #318 (got 20 columns instead of 7)
#     Line #319 (got 14 columns instead of 7)
#     Line #321 (got 1 columns instead of 7)
#     Line #322 (got 1 columns instead of 7)
#     Line #323 (got 3 columns instead of 7)
#     Line #324 (got 4 columns instead of 7)
#     Line #325 (got 1 columns instead of 7)
#     Line #328 (got 1 columns instead of 7)
#     Line #330 (got 1 columns instead of 7)
#     Line #331 (got 4 columns instead of 7)
#     Line #332 (got 4 columns instead of 7)
#     Line #334 (got 1 columns instead of 7)
#     Line #335 (got 20 columns instead of 7)
#     Line #336 (got 2 columns instead of 7)
#     Line #339 (got 1 columns instead of 7)
#     Line #341 (got 1 columns instead of 7)
#     Line #342 (got 19 columns instead of 7)
#     Line #343 (got 1 columns instead of 7)
#     Line #345 (got 14 columns instead of 7)
#     Line #346 (got 40 columns instead of 7)
#     Line #347 (got 1 columns instead of 7)
#     Line #348 (got 1 columns instead of 7)
#     Line #350 (got 1 columns instead of 7)
#     Line #351 (got 21 columns instead of 7)
#     Line #352 (got 2 columns instead of 7)
#     Line #354 (got 14 columns instead of 7)
#     Line #355 (got 40 columns instead of 7)
#     Line #356 (got 1 columns instead of 7)
#     Line #357 (got 1 columns instead of 7)
#     Line #359 (got 1 columns instead of 7)
#     Line #360 (got 19 columns instead of 7)
#     Line #361 (got 1 columns instead of 7)
#     Line #363 (got 14 columns instead of 7)
#     Line #364 (got 40 columns instead of 7)
#     Line #365 (got 1 columns instead of 7)
#     Line #366 (got 1 columns instead of 7)
#     Line #368 (got 1 columns instead of 7)
#     Line #369 (got 1 columns instead of 7)
#     Line #370 (got 1 columns instead of 7)
#     Line #373 (got 12 columns instead of 7)
#     Line #374 (got 16 columns instead of 7)
#     Line #375 (got 1 columns instead of 7)
#     Line #376 (got 15 columns instead of 7)
#     Line #377 (got 18 columns instead of 7)
#     Line #378 (got 1 columns instead of 7)
#     Line #379 (got 1 columns instead of 7)
#     Line #380 (got 13 columns instead of 7)
#     Line #381 (got 6 columns instead of 7)
#     Line #382 (got 5 columns instead of 7)
#     Line #384 (got 1 columns instead of 7)
#     Line #385 (got 18 columns instead of 7)
#     Line #386 (got 1 columns instead of 7)
#     Line #389 (got 1 columns instead of 7)
#     Line #391 (got 1 columns instead of 7)
#     Line #392 (got 18 columns instead of 7)
#     Line #393 (got 1 columns instead of 7)
#     Line #396 (got 1 columns instead of 7)
#     Line #398 (got 1 columns instead of 7)
#     Line #399 (got 20 columns instead of 7)
#     Line #400 (got 2 columns instead of 7)
#     Line #403 (got 1 columns instead of 7)
#     Line #405 (got 1 columns instead of 7)
#     Line #406 (got 6 columns instead of 7)
#     Line #407 (got 5 columns instead of 7)
#     Line #409 (got 1 columns instead of 7)
#     Line #410 (got 23 columns instead of 7)
#     Line #411 (got 3 columns instead of 7)
#     Line #413 (got 14 columns instead of 7)
#     Line #414 (got 40 columns instead of 7)
#     Line #415 (got 1 columns instead of 7)
#     Line #416 (got 1 columns instead of 7)
#     Line #419 (got 1 columns instead of 7)
#     Line #420 (got 19 columns instead of 7)
#     Line #421 (got 1 columns instead of 7)
#     Line #423 (got 14 columns instead of 7)
#     Line #424 (got 40 columns instead of 7)
#     Line #425 (got 1 columns instead of 7)
#     Line #426 (got 1 columns instead of 7)
#     Line #428 (got 1 columns instead of 7)
#     Line #429 (got 19 columns instead of 7)
#     Line #430 (got 1 columns instead of 7)
#     Line #432 (got 14 columns instead of 7)
#     Line #433 (got 40 columns instead of 7)
#     Line #434 (got 1 columns instead of 7)
#     Line #435 (got 1 columns instead of 7)
#     Line #437 (got 1 columns instead of 7)
#     Line #438 (got 4 columns instead of 7)
#     Line #439 (got 5 columns instead of 7)
#     Line #441 (got 1 columns instead of 7)
#     Line #442 (got 20 columns instead of 7)
#     Line #443 (got 2 columns instead of 7)
#     Line #446 (got 1 columns instead of 7)
#     Line #448 (got 1 columns instead of 7)
#     Line #449 (got 19 columns instead of 7)
#     Line #450 (got 1 columns instead of 7)
#     Line #452 (got 14 columns instead of 7)
#     Line #453 (got 40 columns instead of 7)
#     Line #454 (got 1 columns instead of 7)
#     Line #455 (got 1 columns instead of 7)
#     Line #457 (got 1 columns instead of 7)
#     Line #458 (got 1 columns instead of 7)
#     Line #459 (got 1 columns instead of 7)
#     Line #462 (got 12 columns instead of 7)
#     Line #463 (got 16 columns instead of 7)
#     Line #464 (got 2 columns instead of 7)
#     Line #465 (got 15 columns instead of 7)
#     Line #466 (got 18 columns instead of 7)
#     Line #467 (got 1 columns instead of 7)
#     Line #468 (got 1 columns instead of 7)
#     Line #469 (got 13 columns instead of 7)
#     Line #470 (got 6 columns instead of 7)
#     Line #472 (got 1 columns instead of 7)
#     Line #473 (got 23 columns instead of 7)
#     Line #475 (got 1 columns instead of 7)
#     Line #476 (got 4 columns instead of 7)
#     Line #477 (got 4 columns instead of 7)
#     Line #478 (got 1 columns instead of 7)
#     Line #481 (got 1 columns instead of 7)
#     Line #483 (got 1 columns instead of 7)
#     Line #484 (got 6 columns instead of 7)
#     Line #486 (got 1 columns instead of 7)
#     Line #487 (got 25 columns instead of 7)
#     Line #489 (got 1 columns instead of 7)
#     Line #490 (got 5 columns instead of 7)
#     Line #491 (got 3 columns instead of 7)
#     Line #492 (got 1 columns instead of 7)
#     Line #495 (got 1 columns instead of 7)
#     Line #497 (got 1 columns instead of 7)
#     Line #498 (got 4 columns instead of 7)
#     Line #499 (got 4 columns instead of 7)
#     Line #501 (got 1 columns instead of 7)
#     Line #502 (got 19 columns instead of 7)
#     Line #503 (got 1 columns instead of 7)
#     Line #506 (got 1 columns instead of 7)
#     Line #508 (got 1 columns instead of 7)
#     Line #509 (got 19 columns instead of 7)
#     Line #510 (got 1 columns instead of 7)
#     Line #513 (got 1 columns instead of 7)
#     Line #515 (got 1 columns instead of 7)
#     Line #516 (got 19 columns instead of 7)
#     Line #517 (got 1 columns instead of 7)
#     Line #520 (got 1 columns instead of 7)
#     Line #522 (got 1 columns instead of 7)
#     Line #523 (got 1 columns instead of 7)
#     Line #524 (got 1 columns instead of 7)
#     Line #527 (got 12 columns instead of 7)
#     Line #528 (got 20 columns instead of 7)
#     Line #529 (got 1 columns instead of 7)
#     Line #531 (got 1 columns instead of 7)
#     Line #532 (got 1 columns instead of 7)
#     Line #534 (got 9 columns instead of 7)
#     Line #535 (got 5 columns instead of 7)
#     Line #540 (got 14 columns instead of 7)
#     Line #541 (got 1 columns instead of 7)
#     Line #542 (got 2 columns instead of 7)
#     Line #543 (got 17 columns instead of 7)
#     Line #544 (got 11 columns instead of 7)
#     Line #545 (got 2 columns instead of 7)
#     Line #546 (got 7 columns instead of 7)
#     Line #547 (got 1 columns instead of 7)
#     Line #548 (got 1 columns instead of 7)
#     Line #549 (got 1 columns instead of 7)
#     Line #550 (got 1 columns instead of 7)
#     Line #551 (got 2 columns instead of 7)
#     Line #552 (got 1 columns instead of 7)
#     Line #553 (got 1 columns instead of 7)
#     Line #554 (got 1 columns instead of 7)
#     Line #555 (got 1 columns instead of 7)
#     Line #556 (got 1 columns instead of 7)
#     Line #557 (got 1 columns instead of 7)
#     Line #558 (got 1 columns instead of 7)
#     Line #559 (got 1 columns instead of 7)
#     Line #560 (got 1 columns instead of 7)
#     Line #561 (got 1 columns instead of 7)
#     Line #562 (got 1 columns instead of 7)
#     Line #563 (got 1 columns instead of 7)
#     Line #564 (got 6 columns instead of 7)
#     Line #565 (got 5 columns instead of 7)
#     Line #566 (got 9 columns instead of 7)
#     Line #569 (got 7 columns instead of 7)
#     Line #571 (got 3 columns instead of 7)
#     Line #574 (got 10 columns instead of 7)
#     Line #575 (got 12 columns instead of 7)
#     Line #576 (got 7 columns instead of 7)
#     Line #577 (got 17 columns instead of 7)
#     Line #578 (got 43 columns instead of 7)
#     Line #579 (got 1 columns instead of 7)
#     Line #580 (got 17 columns instead of 7)
#     Line #581 (got 52 columns instead of 7)
#     Line #582 (got 1 columns instead of 7)
#     Line #583 (got 17 columns instead of 7)
#     Line #584 (got 20 columns instead of 7)
#     Line #585 (got 1 columns instead of 7)
#     Line #586 (got 1 columns instead of 7)
#     Line #588 (got 11 columns instead of 7)
#     Line #590 (got 9 columns instead of 7)
#     Line #591 (got 1 columns instead of 7)
#     Line #593 (got 11 columns instead of 7)
#     Line #594 (got 6 columns instead of 7)
#     Line #595 (got 3 columns instead of 7)
#     Line #596 (got 1 columns instead of 7)
#     Line #597 (got 7 columns instead of 7)
#     Line #598 (got 2 columns instead of 7)
#     Line #599 (got 1 columns instead of 7)
#     Line #600 (got 5 columns instead of 7)
#     Line #601 (got 1 columns instead of 7)
#     Line #603 (got 13 columns instead of 7)
#     Line #604 (got 2 columns instead of 7)
#     Line #605 (got 4 columns instead of 7)
#     Line #606 (got 1 columns instead of 7)
#     Line #607 (got 1 columns instead of 7)
#     Line #608 (got 1 columns instead of 7)
#     Line #610 (got 1 columns instead of 7)
#     Line #612 (got 3 columns instead of 7)
#     Line #613 (got 8 columns instead of 7)
#     Line #614 (got 6 columns instead of 7)
#     Line #615 (got 1 columns instead of 7)
#     Line #616 (got 1 columns instead of 7)
#     Line #618 (got 8 columns instead of 7)
#     Line #621 (got 11 columns instead of 7)
#     Line #622 (got 12 columns instead of 7)
#     Line #623 (got 7 columns instead of 7)
#     Line #624 (got 17 columns instead of 7)
#     Line #625 (got 43 columns instead of 7)
#     Line #626 (got 1 columns instead of 7)
#     Line #627 (got 17 columns instead of 7)
#     Line #628 (got 52 columns instead of 7)
#     Line #629 (got 1 columns instead of 7)
#     Line #630 (got 17 columns instead of 7)
#     Line #631 (got 20 columns instead of 7)
#     Line #632 (got 1 columns instead of 7)
#     Line #633 (got 1 columns instead of 7)
#     Line #635 (got 11 columns instead of 7)
#     Line #637 (got 9 columns instead of 7)
#     Line #638 (got 1 columns instead of 7)
#     Line #640 (got 11 columns instead of 7)
#     Line #641 (got 6 columns instead of 7)
#     Line #642 (got 3 columns instead of 7)
#     Line #643 (got 1 columns instead of 7)
#     Line #644 (got 7 columns instead of 7)
#     Line #645 (got 2 columns instead of 7)
#     Line #646 (got 1 columns instead of 7)
#     Line #647 (got 5 columns instead of 7)
#     Line #648 (got 1 columns instead of 7)
#     Line #650 (got 13 columns instead of 7)
#     Line #651 (got 2 columns instead of 7)
#     Line #652 (got 4 columns instead of 7)
#     Line #653 (got 1 columns instead of 7)
#     Line #654 (got 1 columns instead of 7)
#     Line #655 (got 1 columns instead of 7)
#     Line #659 (got 11 columns instead of 7)
#     Line #660 (got 12 columns instead of 7)
#     Line #661 (got 7 columns instead of 7)
#     Line #662 (got 17 columns instead of 7)
#     Line #663 (got 43 columns instead of 7)
#     Line #664 (got 1 columns instead of 7)
#     Line #665 (got 17 columns instead of 7)
#     Line #666 (got 52 columns instead of 7)
#     Line #667 (got 1 columns instead of 7)
#     Line #668 (got 17 columns instead of 7)
#     Line #669 (got 20 columns instead of 7)
#     Line #670 (got 1 columns instead of 7)
#     Line #671 (got 1 columns instead of 7)
#     Line #673 (got 11 columns instead of 7)
#     Line #675 (got 9 columns instead of 7)
#     Line #676 (got 1 columns instead of 7)
#     Line #678 (got 11 columns instead of 7)
#     Line #679 (got 6 columns instead of 7)
#     Line #680 (got 3 columns instead of 7)
#     Line #681 (got 1 columns instead of 7)
#     Line #682 (got 7 columns instead of 7)
#     Line #683 (got 2 columns instead of 7)
#     Line #684 (got 1 columns instead of 7)
#     Line #685 (got 5 columns instead of 7)
#     Line #686 (got 1 columns instead of 7)
#     Line #688 (got 13 columns instead of 7)
#     Line #689 (got 2 columns instead of 7)
#     Line #690 (got 4 columns instead of 7)
#     Line #691 (got 1 columns instead of 7)
#     Line #692 (got 1 columns instead of 7)
#     Line #693 (got 1 columns instead of 7)
#     Line #697 (got 11 columns instead of 7)
#     Line #698 (got 12 columns instead of 7)
#     Line #699 (got 7 columns instead of 7)
#     Line #700 (got 17 columns instead of 7)
#     Line #701 (got 43 columns instead of 7)
#     Line #702 (got 1 columns instead of 7)
#     Line #703 (got 17 columns instead of 7)
#     Line #704 (got 52 columns instead of 7)
#     Line #705 (got 1 columns instead of 7)
#     Line #706 (got 17 columns instead of 7)
#     Line #707 (got 20 columns instead of 7)
#     Line #708 (got 1 columns instead of 7)
#     Line #709 (got 1 columns instead of 7)
#     Line #711 (got 11 columns instead of 7)
#     Line #713 (got 9 columns instead of 7)
#     Line #714 (got 1 columns instead of 7)
#     Line #716 (got 11 columns instead of 7)
#     Line #717 (got 6 columns instead of 7)
#     Line #718 (got 3 columns instead of 7)
#     Line #719 (got 1 columns instead of 7)
#     Line #720 (got 7 columns instead of 7)
#     Line #721 (got 2 columns instead of 7)
#     Line #722 (got 1 columns instead of 7)
#     Line #723 (got 5 columns instead of 7)
#     Line #724 (got 1 columns instead of 7)
#     Line #726 (got 13 columns instead of 7)
#     Line #727 (got 2 columns instead of 7)
#     Line #728 (got 4 columns instead of 7)
#     Line #729 (got 1 columns instead of 7)
#     Line #730 (got 1 columns instead of 7)
#     Line #731 (got 1 columns instead of 7)
#     Line #734 (got 1 columns instead of 7)
#     Line #736 (got 1 columns instead of 7)
#     Line #737 (got 1 columns instead of 7)
#     Line #738 (got 2 columns instead of 7)
#     Line #739 (got 1 columns instead of 7)
#     Line #741 (got 1 columns instead of 7)
#     Line #743 (got 4 columns instead of 7)
#     Line #744 (got 2 columns instead of 7)
#     Line #745 (got 12 columns instead of 7)
#     Line #746 (got 4 columns instead of 7)
#     Line #747 (got 7 columns instead of 7)
#     Line #748 (got 2 columns instead of 7)
#     Line #749 (got 1 columns instead of 7)
#     Line #750 (got 1 columns instead of 7)
#     Line #752 (got 2 columns instead of 7)
#     Line #753 (got 11 columns instead of 7)
#     Line #754 (got 4 columns instead of 7)
#     Line #755 (got 10 columns instead of 7)
#     Line #756 (got 1 columns instead of 7)
#     Line #757 (got 2 columns instead of 7)
#     Line #758 (got 1 columns instead of 7)
#     Line #759 (got 1 columns instead of 7)
#     Line #760 (got 1 columns instead of 7)
#     Line #761 (got 1 columns instead of 7)
#     Line #762 (got 1 columns instead of 7)
#     Line #763 (got 1 columns instead of 7)
#     Line #765 (got 1 columns instead of 7)
#     Line #767 (got 3 columns instead of 7)
#     Line #775 (got 3 columns instead of 7)
#     Line #780 (got 2 columns instead of 7)
#     Line #782 (got 6 columns instead of 7)
#     Line #783 (got 3 columns instead of 7)
#     Line #784 (got 8 columns instead of 7)
#     Line #785 (got 12 columns instead of 7)
#     Line #786 (got 25 columns instead of 7)
#     Line #787 (got 1 columns instead of 7)
#     Line #788 (got 1 columns instead of 7)
#     Line #789 (got 4 columns instead of 7)
#     Line #791 (got 3 columns instead of 7)
#     Line #793 (got 1 columns instead of 7)
#     Line #794 (got 1 columns instead of 7)
#     Line #795 (got 1 columns instead of 7)
#     Line #796 (got 1 columns instead of 7)
#     Line #797 (got 1 columns instead of 7)
#     Line #801 (got 3 columns instead of 7)
#     Line #808 (got 1 columns instead of 7)
#     Line #809 (got 2 columns instead of 7)
#     Line #810 (got 1 columns instead of 7)
#     Line #811 (got 1 columns instead of 7)
#     Line #812 (got 1 columns instead of 7)
#     Line #813 (got 1 columns instead of 7)
#     Line #814 (got 4 columns instead of 7)
#     Line #815 (got 3 columns instead of 7)
#     Line #826 (got 7 columns instead of 7)
#     Line #828 (got 10 columns instead of 7)
#     Line #830 (got 5 columns instead of 7)
#     Line #832 (got 8 columns instead of 7)
#     Line #833 (got 14 columns instead of 7)
#     Line #834 (got 43 columns instead of 7)
#     Line #835 (got 1 columns instead of 7)
#     Line #837 (got 4 columns instead of 7)
#     Line #838 (got 9 columns instead of 7)
#     Line #839 (got 1 columns instead of 7)
#     Line #840 (got 4 columns instead of 7)
#     Line #841 (got 4 columns instead of 7)
#     Line #842 (got 2 columns instead of 7)
#     Line #843 (got 1 columns instead of 7)
#     Line #845 (got 5 columns instead of 7)
#     Line #846 (got 1 columns instead of 7)
#     Line #849 (got 1 columns instead of 7)
#     Line #851 (got 8 columns instead of 7)
#     Line #855 (got 1 columns instead of 7)
#     Line #856 (got 35 columns instead of 7)
#     Line #857 (got 55 columns instead of 7)
#     Line #858 (got 1 columns instead of 7)
#     Line #859 (got 1 columns instead of 7)
#     Line #860 (got 1 columns instead of 7)
#     Line #862 (got 1 columns instead of 7)
#     Line #863 (got 36 columns instead of 7)
#     Line #864 (got 49 columns instead of 7)
#     Line #865 (got 1 columns instead of 7)
#     Line #866 (got 7 columns instead of 7)
#     Line #867 (got 1 columns instead of 7)
#     Line #868 (got 1 columns instead of 7)
#     Line #870 (got 1 columns instead of 7)
#     Line #871 (got 4 columns instead of 7)
#     Line #872 (got 36 columns instead of 7)
#     Line #873 (got 44 columns instead of 7)
#     Line #874 (got 3 columns instead of 7)
#     Line #875 (got 1 columns instead of 7)
#     Line #876 (got 21 columns instead of 7)
#     Line #877 (got 33 columns instead of 7)
#     Line #878 (got 12 columns instead of 7)
#     Line #879 (got 1 columns instead of 7)
#     Line #880 (got 1 columns instead of 7)
#     Line #881 (got 1 columns instead of 7)
#     Line #885 (got 1 columns instead of 7)
#     Line #887 (got 1 columns instead of 7)
#     Line #889 (got 3 columns instead of 7)
#     Line #890 (got 1 columns instead of 7)
#     Line #893 (got 2 columns instead of 7)
#     Line #895 (got 4 columns instead of 7)
#     Line #896 (got 3 columns instead of 7)
#     Line #897 (got 14 columns instead of 7)
#     Line #899 (got 15 columns instead of 7)
#     Line #900 (got 26 columns instead of 7)
#     Line #901 (got 1 columns instead of 7)
#     Line #902 (got 2 columns instead of 7)
#     Line #903 (got 8 columns instead of 7)
#     Line #907 (got 1 columns instead of 7)
#     Line #908 (got 3 columns instead of 7)
#     Line #909 (got 9 columns instead of 7)
#     Line #911 (got 15 columns instead of 7)
#     Line #912 (got 32 columns instead of 7)
#     Line #913 (got 1 columns instead of 7)
#     Line #914 (got 2 columns instead of 7)
#     Line #915 (got 8 columns instead of 7)
#     Line #919 (got 1 columns instead of 7)
#     Line #920 (got 3 columns instead of 7)
#     Line #921 (got 8 columns instead of 7)
#     Line #923 (got 15 columns instead of 7)
#     Line #924 (got 57 columns instead of 7)
#     Line #925 (got 1 columns instead of 7)
#     Line #926 (got 4 columns instead of 7)
#     Line #927 (got 8 columns instead of 7)
#     Line #931 (got 1 columns instead of 7)
#     Line #932 (got 3 columns instead of 7)
#     Line #933 (got 7 columns instead of 7)
#     Line #935 (got 15 columns instead of 7)
#     Line #936 (got 31 columns instead of 7)
#     Line #937 (got 1 columns instead of 7)
#     Line #938 (got 2 columns instead of 7)
#     Line #939 (got 8 columns instead of 7)
#     Line #943 (got 1 columns instead of 7)
#     Line #944 (got 3 columns instead of 7)
#     Line #945 (got 9 columns instead of 7)
#     Line #947 (got 15 columns instead of 7)
#     Line #948 (got 31 columns instead of 7)
#     Line #949 (got 1 columns instead of 7)
#     Line #950 (got 2 columns instead of 7)
#     Line #951 (got 8 columns instead of 7)
#     Line #955 (got 1 columns instead of 7)
#     Line #956 (got 3 columns instead of 7)
#     Line #957 (got 12 columns instead of 7)
#     Line #959 (got 15 columns instead of 7)
#     Line #961 (got 1 columns instead of 7)
#     Line #962 (got 2 columns instead of 7)
#     Line #963 (got 3 columns instead of 7)
#     Line #966 (got 1 columns instead of 7)
#     Line #967 (got 3 columns instead of 7)
#     Line #968 (got 13 columns instead of 7)
#     Line #970 (got 15 columns instead of 7)
#     Line #971 (got 28 columns instead of 7)
#     Line #972 (got 1 columns instead of 7)
#     Line #973 (got 2 columns instead of 7)
#     Line #974 (got 8 columns instead of 7)
#     Line #978 (got 1 columns instead of 7)
#     Line #979 (got 1 columns instead of 7)
#     Line #980 (got 15 columns instead of 7)
#     Line #981 (got 7 columns instead of 7)
#     Line #982 (got 12 columns instead of 7)
#     Line #983 (got 29 columns instead of 7)
#     Line #984 (got 1 columns instead of 7)
#     Line #985 (got 2 columns instead of 7)
#     Line #986 (got 1 columns instead of 7)
#     Line #987 (got 1 columns instead of 7)
#     Line #988 (got 6 columns instead of 7)
#     Line #989 (got 3 columns instead of 7)
#     Line #990 (got 16 columns instead of 7)
#     Line #991 (got 1 columns instead of 7)
#     Line #992 (got 2 columns instead of 7)
#     Line #993 (got 3 columns instead of 7)
#     Line #994 (got 9 columns instead of 7)
#     Line #995 (got 1 columns instead of 7)
#     Line #996 (got 2 columns instead of 7)
#     Line #997 (got 3 columns instead of 7)
#     Line #998 (got 8 columns instead of 7)
#     Line #999 (got 2 columns instead of 7)
#     Line #1000 (got 2 columns instead of 7)
#     Line #1001 (got 3 columns instead of 7)
#     Line #1002 (got 7 columns instead of 7)
#     Line #1003 (got 1 columns instead of 7)
#     Line #1004 (got 2 columns instead of 7)
#     Line #1005 (got 3 columns instead of 7)
#     Line #1006 (got 9 columns instead of 7)
#     Line #1007 (got 1 columns instead of 7)
#     Line #1008 (got 2 columns instead of 7)
#     Line #1009 (got 3 columns instead of 7)
#     Line #1010 (got 12 columns instead of 7)
#     Line #1011 (got 1 columns instead of 7)
#     Line #1012 (got 2 columns instead of 7)
#     Line #1013 (got 3 columns instead of 7)
#     Line #1014 (got 13 columns instead of 7)
#     Line #1015 (got 1 columns instead of 7)
#     Line #1016 (got 2 columns instead of 7)
#     Line #1017 (got 1 columns instead of 7)
#     Line #1018 (got 1 columns instead of 7)
#     Line #1019 (got 1 columns instead of 7)
#     Line #1020 (got 1 columns instead of 7)
#     Line #1024 (got 1 columns instead of 7)
#     Line #1028 (got 5 columns instead of 7)
#     Line #1029 (got 5 columns instead of 7)
#     Line #1036 (got 7 columns instead of 7)
#     Line #1039 (got 2 columns instead of 7)
#     Line #1048 (got 5 columns instead of 7)
#     Line #1050 (got 9 columns instead of 7)
#     Line #1052 (got 2 columns instead of 7)
#     Line #1053 (got 1 columns instead of 7)
#     Line #1054 (got 6 columns instead of 7)
#     Line #1055 (got 1 columns instead of 7)
#     Line #1056 (got 2 columns instead of 7)
#     Line #1057 (got 3 columns instead of 7)
#     Line #1058 (got 1 columns instead of 7)
#     Line #1059 (got 4 columns instead of 7)
#     Line #1060 (got 13 columns instead of 7)
#     Line #1061 (got 54 columns instead of 7)
#     Line #1062 (got 1 columns instead of 7)
#     Line #1063 (got 3 columns instead of 7)
#     Line #1064 (got 2 columns instead of 7)
#     Line #1065 (got 1 columns instead of 7)
#     Line #1068 (got 2 columns instead of 7)
#     Line #1069 (got 2 columns instead of 7)
#     Line #1070 (got 2 columns instead of 7)
#     Line #1071 (got 3 columns instead of 7)
#     Line #1072 (got 18 columns instead of 7)
#     Line #1073 (got 25 columns instead of 7)
#     Line #1074 (got 1 columns instead of 7)
#     Line #1075 (got 1 columns instead of 7)
#     Line #1077 (got 2 columns instead of 7)
#     Line #1078 (got 6 columns instead of 7)
#     Line #1079 (got 2 columns instead of 7)
#     Line #1080 (got 2 columns instead of 7)
#     Line #1081 (got 1 columns instead of 7)
#     Line #1082 (got 2 columns instead of 7)
#     Line #1083 (got 1 columns instead of 7)
#     Line #1084 (got 1 columns instead of 7)
#     Line #1085 (got 1 columns instead of 7)
#     Line #1086 (got 1 columns instead of 7)
#     Line #1087 (got 2 columns instead of 7)
#     Line #1088 (got 2 columns instead of 7)
#     Line #1089 (got 1 columns instead of 7)
#     Line #1090 (got 1 columns instead of 7)
#     Line #1091 (got 1 columns instead of 7)
#     Line #1093 (got 5 columns instead of 7)
#     Line #1094 (got 5 columns instead of 7)
#     Line #1095 (got 4 columns instead of 7)
#     Line #1096 (got 1 columns instead of 7)
#     Line #1098 (got 10 columns instead of 7)
#     Line #1099 (got 1 columns instead of 7)
#     Line #1100 (got 1 columns instead of 7)
#     Line #1101 (got 1 columns instead of 7)
#     Line #1102 (got 1 columns instead of 7)
#     Line #1103 (got 1 columns instead of 7)
#     Line #1104 (got 1 columns instead of 7)
#     Line #1105 (got 1 columns instead of 7)
#     Line #1106 (got 1 columns instead of 7)
#     Line #1107 (got 1 columns instead of 7)
#     Line #1109 (got 1 columns instead of 7)
#     Line #1110 (got 1 columns instead of 7)
#     Line #1111 (got 1 columns instead of 7)
#     Line #1112 (got 1 columns instead of 7)
#     Line #1113 (got 1 columns instead of 7)
#     Line #1114 (got 1 columns instead of 7)
#     Line #1116 (got 2 columns instead of 7)
#     Line #1117 (got 8 columns instead of 7)
#     Line #1118 (got 1 columns instead of 7)
#     Line #1120 (got 2 columns instead of 7)
#     Line #1121 (got 4 columns instead of 7)
#     Line #1122 (got 1 columns instead of 7)
#     Line #1125 (got 6 columns instead of 7)
#     Line #1126 (got 8 columns instead of 7)
#     Line #1127 (got 14 columns instead of 7)
#     Line #1128 (got 9 columns instead of 7)
#     Line #1129 (got 11 columns instead of 7)
#     Line #1130 (got 1 columns instead of 7)
#     Line #1131 (got 1 columns instead of 7)
#     Line #1132 (got 1 columns instead of 7)
#     Line #1134 (got 2 columns instead of 7)
#     Line #1135 (got 13 columns instead of 7)
#     Line #1136 (got 14 columns instead of 7)
#     Line #1137 (got 18 columns instead of 7)
#     Line #1138 (got 1 columns instead of 7)
#     Line #1139 (got 9 columns instead of 7)
#     Line #1140 (got 7 columns instead of 7)
#     Line #1141 (got 1 columns instead of 7)
#     Line #1142 (got 1 columns instead of 7)
#     Line #1145 (got 5 columns instead of 7)
#     Line #1146 (got 1 columns instead of 7)
#     Line #1148 (got 1 columns instead of 7)
#     Line #1150 (got 12 columns instead of 7)
#     Line #1151 (got 1 columns instead of 7)
#     Line #1152 (got 1 columns instead of 7)
#     Line #1153 (got 1 columns instead of 7)
#     Line #1154 (got 1 columns instead of 7)
#     Line #1155 (got 1 columns instead of 7)
#     Line #1156 (got 1 columns instead of 7)
#     Line #1157 (got 1 columns instead of 7)
#     Line #1158 (got 1 columns instead of 7)
#     Line #1159 (got 1 columns instead of 7)
#     Line #1160 (got 1 columns instead of 7)
#     Line #1161 (got 1 columns instead of 7)
#     Line #1162 (got 1 columns instead of 7)
#     Line #1163 (got 1 columns instead of 7)
#     Line #1164 (got 1 columns instead of 7)
#     Line #1166 (got 2 columns instead of 7)
#     Line #1167 (got 8 columns instead of 7)
#     Line #1168 (got 1 columns instead of 7)
#     Line #1170 (got 2 columns instead of 7)
#     Line #1171 (got 7 columns instead of 7)
#     Line #1172 (got 1 columns instead of 7)
#     Line #1174 (got 2 columns instead of 7)
#     Line #1175 (got 13 columns instead of 7)
#     Line #1176 (got 14 columns instead of 7)
#     Line #1177 (got 18 columns instead of 7)
#     Line #1178 (got 1 columns instead of 7)
#     Line #1179 (got 9 columns instead of 7)
#     Line #1180 (got 7 columns instead of 7)
#     Line #1181 (got 1 columns instead of 7)
#     Line #1182 (got 1 columns instead of 7)
#     Line #1185 (got 5 columns instead of 7)
#     Line #1186 (got 8 columns instead of 7)
#     Line #1187 (got 14 columns instead of 7)
#     Line #1188 (got 9 columns instead of 7)
#     Line #1189 (got 11 columns instead of 7)
#     Line #1190 (got 1 columns instead of 7)
#     Line #1191 (got 1 columns instead of 7)
#     Line #1192 (got 1 columns instead of 7)
#     Line #1193 (got 5 columns instead of 7)
#     Line #1194 (got 1 columns instead of 7)
#     Line #1195 (got 1 columns instead of 7)
#     Line #1196 (got 1 columns instead of 7)
#     Line #1197 (got 1 columns instead of 7)
#     Line #1198 (got 1 columns instead of 7)
#     Line #1199 (got 1 columns instead of 7)
#     Line #1201 (got 1 columns instead of 7)
#     Line #1203 (got 1 columns instead of 7)
#     Line #1206 (got 4 columns instead of 7)
#     Line #1207 (got 10 columns instead of 7)
#     Line #1208 (got 4 columns instead of 7)
#     Line #1209 (got 2 columns instead of 7)
#     Line #1210 (got 2 columns instead of 7)
#     Line #1211 (got 6 columns instead of 7)
#     Line #1212 (got 1 columns instead of 7)
#     Line #1213 (got 2 columns instead of 7)
#     Line #1214 (got 18 columns instead of 7)
#     Line #1215 (got 25 columns instead of 7)
#     Line #1216 (got 1 columns instead of 7)
#     Line #1217 (got 1 columns instead of 7)
#     Line #1218 (got 1 columns instead of 7)
#     Line #1219 (got 1 columns instead of 7)
#     Line #1220 (got 3 columns instead of 7)
#     Line #1222 (got 37 columns instead of 7)
#     Line #1223 (got 1 columns instead of 7)
#     Line #1225 (got 1 columns instead of 7)
#     Line #1226 (got 3 columns instead of 7)
#     Line #1227 (got 6 columns instead of 7)
#     Line #1228 (got 1 columns instead of 7)
#     Line #1229 (got 7 columns instead of 7)
#     Line #1230 (got 1 columns instead of 7)
#     Line #1231 (got 1 columns instead of 7)
#     Line #1232 (got 1 columns instead of 7)
#     Line #1235 (got 14 columns instead of 7)
#     Line #1236 (got 7 columns instead of 7)
#     Line #1237 (got 1 columns instead of 7)
#     Line #1238 (got 12 columns instead of 7)
#     Line #1239 (got 1 columns instead of 7)
#     Line #1240 (got 6 columns instead of 7)
#     Line #1241 (got 18 columns instead of 7)
#     Line #1242 (got 29 columns instead of 7)
#     Line #1243 (got 1 columns instead of 7)
#     Line #1244 (got 1 columns instead of 7)
#     Line #1245 (got 5 columns instead of 7)
#     Line #1246 (got 3 columns instead of 7)
#     Line #1247 (got 14 columns instead of 7)
#     Line #1248 (got 4 columns instead of 7)
#     Line #1249 (got 4 columns instead of 7)
#     Line #1250 (got 2 columns instead of 7)
#     Line #1251 (got 2 columns instead of 7)
#     Line #1252 (got 9 columns instead of 7)
#     Line #1253 (got 4 columns instead of 7)
#     Line #1254 (got 4 columns instead of 7)
#     Line #1255 (got 1 columns instead of 7)
#     Line #1256 (got 2 columns instead of 7)
#     Line #1257 (got 3 columns instead of 7)
#     Line #1258 (got 1 columns instead of 7)
#     Line #1259 (got 8 columns instead of 7)
#     Line #1261 (got 2 columns instead of 7)
#     Line #1263 (got 2 columns instead of 7)
#     Line #1264 (got 1 columns instead of 7)
#     Line #1265 (got 8 columns instead of 7)
#     Line #1267 (got 3 columns instead of 7)
#     Line #1268 (got 3 columns instead of 7)
#     Line #1269 (got 1 columns instead of 7)
#     Line #1271 (got 2 columns instead of 7)
#     Line #1272 (got 1 columns instead of 7)
#     Line #1273 (got 1 columns instead of 7)
#     Line #1274 (got 1 columns instead of 7)
#     Line #1280 (got 6 columns instead of 7)
#     Line #1281 (got 6 columns instead of 7)
#     Line #1284 (got 14 columns instead of 7)
#     Line #1285 (got 41 columns instead of 7)
#     Line #1286 (got 1 columns instead of 7)
#     Line #1288 (got 22 columns instead of 7)
#     Line #1292 (got 1 columns instead of 7)
#     Line #1294 (got 3 columns instead of 7)
#     Line #1296 (got 6 columns instead of 7)
#     Line #1297 (got 3 columns instead of 7)
#     Line #1298 (got 4 columns instead of 7)
#     Line #1299 (got 10 columns instead of 7)
#     Line #1300 (got 5 columns instead of 7)
#     Line #1301 (got 1 columns instead of 7)
#     Line #1303 (got 5 columns instead of 7)
#     Line #1304 (got 4 columns instead of 7)
#     Line #1305 (got 9 columns instead of 7)
#     Line #1306 (got 1 columns instead of 7)
#     Line #1307 (got 1 columns instead of 7)
#     Line #1317 (got 5 columns instead of 7)
#     Line #1319 (got 1 columns instead of 7)
#     Line #1320 (got 8 columns instead of 7)
#     Line #1322 (got 1 columns instead of 7)
#     Line #1325 (got 7 columns instead of 7)
#     Line #1327 (got 2 columns instead of 7)
#     Line #1328 (got 1 columns instead of 7)
#     Line #1330 (got 11 columns instead of 7)
#     Line #1333 (got 2 columns instead of 7)
#     Line #1334 (got 8 columns instead of 7)
#     Line #1335 (got 2 columns instead of 7)
#     Line #1337 (got 2 columns instead of 7)
#     Line #1338 (got 7 columns instead of 7)
#     Line #1339 (got 10 columns instead of 7)
#     Line #1340 (got 12 columns instead of 7)
#     Line #1341 (got 42 columns instead of 7)
#     Line #1342 (got 1 columns instead of 7)
#     Line #1343 (got 1 columns instead of 7)
#     Line #1344 (got 1 columns instead of 7)
#     Line #1345 (got 1 columns instead of 7)
#     Line #1347 (got 6 columns instead of 7)
#     Line #1348 (got 5 columns instead of 7)
#     Line #1349 (got 1 columns instead of 7)
#     Line #1350 (got 2 columns instead of 7)
#     Line #1351 (got 1 columns instead of 7)
#     Line #1352 (got 2 columns instead of 7)
#     Line #1353 (got 1 columns instead of 7)
#     Line #1354 (got 1 columns instead of 7)
#     Line #1355 (got 1 columns instead of 7)
#     Line #1356 (got 12 columns instead of 7)
#     Line #1357 (got 29 columns instead of 7)
#     Line #1358 (got 1 columns instead of 7)
#     Line #1359 (got 1 columns instead of 7)
#     Line #1361 (got 5 columns instead of 7)
#     Line #1362 (got 1 columns instead of 7)
#     Line #1363 (got 1 columns instead of 7)
#     Line #1364 (got 1 columns instead of 7)
#     Line #1365 (got 3 columns instead of 7)
#     Line #1366 (got 1 columns instead of 7)
#     Line #1367 (got 1 columns instead of 7)
#     Line #1368 (got 1 columns instead of 7)
#     Line #1370 (got 1 columns instead of 7)
#     Line #1371 (got 1 columns instead of 7)
#     Line #1372 (got 1 columns instead of 7)
#     Line #1373 (got 1 columns instead of 7)
#     Line #1377 (got 8 columns instead of 7)
#     Line #1379 (got 4 columns instead of 7)
#     Line #1380 (got 3 columns instead of 7)
#     Line #1381 (got 14 columns instead of 7)
#     Line #1382 (got 1 columns instead of 7)
#     Line #1383 (got 1 columns instead of 7)
#     Line #1385 (got 1 columns instead of 7)
#     Line #1390 (got 5 columns instead of 7)
#     Line #1391 (got 5 columns instead of 7)
#     Line #1392 (got 11 columns instead of 7)
#     Line #1393 (got 12 columns instead of 7)
#     Line #1394 (got 14 columns instead of 7)
#     Line #1395 (got 6 columns instead of 7)
#     Line #1396 (got 1 columns instead of 7)
#     Line #1397 (got 2 columns instead of 7)
#     Line #1398 (got 1 columns instead of 7)
#     Line #1402 (got 1 columns instead of 7)
#     Line #1404 (got 1 columns instead of 7)
#     Line #1407 (got 1 columns instead of 7)
#     Line #1409 (got 1 columns instead of 7)
#     Line #1412 (got 1 columns instead of 7)
#     Line #1413 (got 1 columns instead of 7)
#     Line #1415 (got 1 columns instead of 7)
#     Line #1417 (got 5 columns instead of 7)
#     Line #1418 (got 2 columns instead of 7)
#     Line #1420 (got 15 columns instead of 7)
#     Line #1421 (got 10 columns instead of 7)
#     Line #1422 (got 5 columns instead of 7)
#     Line #1423 (got 6 columns instead of 7)
#     Line #1424 (got 12 columns instead of 7)
#     Line #1425 (got 54 columns instead of 7)
#     Line #1426 (got 1 columns instead of 7)
#     Line #1427 (got 2 columns instead of 7)
#     Line #1428 (got 4 columns instead of 7)
#     Line #1429 (got 1 columns instead of 7)
#     Line #1430 (got 1 columns instead of 7)
#     Line #1431 (got 1 columns instead of 7)
#     Line #1433 (got 4 columns instead of 7)
#     Line #1434 (got 4 columns instead of 7)
#     Line #1435 (got 10 columns instead of 7)
#     Line #1436 (got 7 columns instead of 7)
#     Line #1437 (got 7 columns instead of 7)
#     Line #1438 (got 7 columns instead of 7)
#     Line #1439 (got 7 columns instead of 7)
#     Line #1440 (got 9 columns instead of 7)
#     Line #1441 (got 8 columns instead of 7)
#     Line #1442 (got 7 columns instead of 7)
#     Line #1443 (got 7 columns instead of 7)
#     Line #1444 (got 7 columns instead of 7)
#     Line #1445 (got 7 columns instead of 7)
#     Line #1446 (got 7 columns instead of 7)
#     Line #1447 (got 1 columns instead of 7)
#     Line #1448 (got 1 columns instead of 7)
#     Line #1449 (got 1 columns instead of 7)
#     Line #1451 (got 4 columns instead of 7)
#     Line #1452 (got 3 columns instead of 7)
#     Line #1453 (got 1 columns instead of 7)
#     Line #1454 (got 1 columns instead of 7)
#     Line #1459 (got 6 columns instead of 7)
#     Line #1460 (got 12 columns instead of 7)
#     Line #1461 (got 41 columns instead of 7)
#     Line #1462 (got 1 columns instead of 7)
#     Line #1463 (got 6 columns instead of 7)
#     Line #1464 (got 12 columns instead of 7)
#     Line #1465 (got 25 columns instead of 7)
#     Line #1466 (got 1 columns instead of 7)
#     Line #1467 (got 1 columns instead of 7)
#     Line #1468 (got 8 columns instead of 7)
#     Line #1469 (got 1 columns instead of 7)
#     Line #1471 (got 6 columns instead of 7)
#     Line #1472 (got 1 columns instead of 7)
#     Line #1473 (got 12 columns instead of 7)
#     Line #1474 (got 41 columns instead of 7)
#     Line #1475 (got 1 columns instead of 7)
#     Line #1476 (got 16 columns instead of 7)
#     Line #1477 (got 16 columns instead of 7)
#     Line #1478 (got 1 columns instead of 7)
#     Line #1479 (got 2 columns instead of 7)
#     Line #1480 (got 8 columns instead of 7)
#     Line #1481 (got 4 columns instead of 7)
#     Line #1482 (got 9 columns instead of 7)
#     Line #1483 (got 11 columns instead of 7)
#     Line #1484 (got 12 columns instead of 7)
#     Line #1485 (got 25 columns instead of 7)
#     Line #1486 (got 1 columns instead of 7)
#     Line #1487 (got 1 columns instead of 7)
#     Line #1488 (got 4 columns instead of 7)
#     Line #1489 (got 1 columns instead of 7)
#     Line #1490 (got 1 columns instead of 7)
#     Line #1491 (got 1 columns instead of 7)
#     Line #1493 (got 9 columns instead of 7)
#     Line #1494 (got 7 columns instead of 7)
#     Line #1495 (got 1 columns instead of 7)
#     Line #1496 (got 1 columns instead of 7)
#     Line #1498 (got 2 columns instead of 7)
#     Line #1499 (got 5 columns instead of 7)
#     Line #1500 (got 10 columns instead of 7)
#     Line #1501 (got 14 columns instead of 7)
#     Line #1502 (got 55 columns instead of 7)
#     Line #1503 (got 1 columns instead of 7)
#     Line #1504 (got 16 columns instead of 7)
#     Line #1505 (got 18 columns instead of 7)
#     Line #1506 (got 1 columns instead of 7)
#     Line #1507 (got 1 columns instead of 7)
#     Line #1508 (got 1 columns instead of 7)
#     Line #1509 (got 1 columns instead of 7)
#     Line #1514 (got 1 columns instead of 7)
#     Line #1515 (got 1 columns instead of 7)

# %%
fig, ax = plt.subplots(1,1,figsize=(12,8))
plt.rcParams.update({'font.size':18})
plt.rcParams.update({'font.family':'Times New Roman'})

ax.set_xlim(0,1)
ax.set_ylim(0,300)

#MESA solar model
mesa = read_model('04-MESAdatafile.txt')

#In the mesa model, the first element [0] correspond to the surface,
#and the last element [mesa.size-1] correspond to the center.

mesa_r = 10**(mesa['logR']-mesa['logR'][0])
mesa_rho = 10**(mesa['logRho']) #the density is given in cgs
ax.plot(mesa_r, mesa_rho, c="red", lw=2, label='MESA')

print ("n",'\t','theta1','\t','\t','central density\n')

n=[0.5,1,1.5,2,2.5,2.75,3,3.5,4]

for item in n:
    eps, theta, theta_prim = poly_num(item)
    eps1 = eps[eps.size-1]
    theta1 = -eps1/theta_prim[eps.size-1]
    rho_c = 0.25 * theta1 * u.Msun / np.pi / u.Rsun**3
    print(item, '\t',theta1, '\t', rho_c.cgs)
    str1=('n=%d (numerical)')%item
    ax.plot(eps/eps1, rho_c.cgs*theta**item,ls='--',label=str1)
rho_mn = 0.75 * u.Msun / np.pi / u.Rsun**3
print('\nMean density is', rho_mn, "\nIn cgs units", rho_mn.cgs)
print('theta1 is the degree of central concentration')
plt.xlabel('eps/eps1')
plt.ylabel('Mean density in g/cm3')
